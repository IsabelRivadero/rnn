# %% [markdown]
# # Caos I
#
# ## **Ejercicio 1)** Importando librerías
#
# Importe las librerías `numpy` para operar con arrays y `matplotlib.pyplot` para graficar.

# %%
import numpy as np
#import scipy as sp
#import scipy.linalg as linalg
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Ejercicio 2)** El mapa logístico
#
# ### Teoría
#
# #### Dinámicas a tiempo discreto.
#
# Nos interesa considerar dinámicas a tiempos discretos.
# Estas suelen estar determinadas por ecuaciones de la forma
#
# \begin{eqnarray}
# x_{t+1}
# &=&
# f(x_t)
# \end{eqnarray}
#
# donde $x_t\in X$ especifica el estado del sistema para cada tiempo $t\in\{0,1,2,...\}$.
#
# Para obtener una trayectoria del sistema anterior, se elige una condición inicial $x_0$ y se itera el mapa para obtener $x_1$, $x_2$, ..., $x_t$, ..., etc.
#
# #### Ciclos límites
#
# Un punto fijo $x^*$ de una dinámica a tiempos discretos queda definido por la condición
#
# \begin{eqnarray}
# x^*&=&f(x^*)
# \end{eqnarray}
#
# Un ciclo límite de período 2 queda definido por las condiciones
#
# \begin{eqnarray}
# x^*&=&f(f(x^*))
# \end{eqnarray}
#
# y
#
# \begin{eqnarray}
# x^*&\neq &f(x^*)
# \end{eqnarray}
#
# para algún $x^*$.
#
# Más generalmente, un ciclo límite de período $n$ queda definido por las condiciones
#
# \begin{eqnarray}
# x^*&=&f_n(x^*)
# \end{eqnarray}
#
# y
#
# \begin{eqnarray}
# x^*&=&f_{n-1}(x^*)
# \end{eqnarray}
#
# para algún $x^*$, donde $f_n(x) = f(f_{n-1}(x))$ para todo $x$ y $n>1$, y $f_1=f$.
#
# #### Estabilidad de los ciclos límites
#
# Sea $x^*$ un ciclo límite de período $n$.
# Luego
#
# \begin{eqnarray}
# x^*+\epsilon_{t+1}
# &=&
# f_n(x^*+\epsilon_t)
# \\
# &=&
# f_n(x^*)
# +
# f_n'(x^*)\epsilon_t
# +
# ...
# \\
# &=&
# x^*
# +
# f_n'(x^*)\epsilon_t
# +
# ...
# \end{eqnarray}
#
# Entonces
#
# \begin{eqnarray}
# \epsilon_{t+1}
# &=&
# f_n'(x^*)\epsilon_t
# +
# ...
# \\
# \bigg|
# \epsilon_{t+1}
# \bigg|
# &=&
# \bigg|
# f_n'(x^*)\epsilon_t
# +
# ...
# \bigg|
# \\
# \bigg|
# \epsilon_{t+1}
# \bigg|
# &\leq &
# \bigg|
# f_n'(x^*)\epsilon_t
# \bigg|
# +
# ...
# \\
# \bigg|
# \epsilon_{t+1}
# \bigg|
# &\leq &
# \bigg|
# f_n'(x^*)
# \bigg|
# \bigg|
# \epsilon_t
# \bigg|
# +
# ...
# \end{eqnarray}
#
# Entonces, si $\epsilon_t$ es lo suficientemente chico como para poder despreciar los ordenes superiores, se obtiene que $|\epsilon_t|$ decrece con $t$ si $|f'(x^*)| < 1$, en cuyo caso se dice que $x^*$ pertenece a un ciclo límite linealmente estable.
#
# Por el contrario, $|\epsilon_t|$ crece con $t$ si $|f'(x^*)| > 1$, en cuyo caso se dice que $x^*$ pertenece a un ciclo límite linealmente inestable.
#
# Si $|f'(x^*)| = 1$, se dice que el ciclo límite es linealmente marginal.
# En cuyo caso se necesitan considerar derivadas de órdenes superiores para poder determinar la estabilidad del ciclo límite.
#
# #### El mapa logístico
#
# El mapa logístico constituye una ecuación a tiempos discretos en donde $X=[0,1]$,
#
# \begin{eqnarray}
# x_{t+1}
# &=&
# f(x_t)
# \\
# &=&
# rx_t(1-x_t)
# \end{eqnarray}
#
# y $r\in [0,4]$ es un parámetro.
#
# **a)** Encuentre los puntos fijos (ciclos límite de período 1) de la ecuación logística.
#
# **b)** Determine la estabilidad de los mismos.
#
# **c)** Compute y grafique 100 pasos temporales de las trayectorias para:
#
# &nbsp; &nbsp; **i)** $x_0=0.8$ y $r=1$,
#
# &nbsp; &nbsp; **ii)** $x_0=0.1$ y $r=3$, y
#
# &nbsp; &nbsp; **iii)** $x_0=0.75$ y $r=3.8$.
#
# **d)** Compute y grafique 100 pasos temporales del diagrama de Verhulst para:
#
# &nbsp; &nbsp; **i)** $x_0=0.8$ y $r=1.1$,
#
# &nbsp; &nbsp; **ii)** $x_0=0.1$ y $r=3.5$, y
#
# &nbsp; &nbsp; **iii)** $x_0=0.75$ y $r=3.8$.
#
# **e)** Grafique el diagrama de bifurcaciones del mapa logístico.
#
# **f)** Grafique el exponente de Lyapunov vs $r$ del mapa logístico. El exponente se define por
#
# \begin{eqnarray}
# \lambda
# &=&
# \lim_{n\to \infty}
# \frac{1}{n}
# \sum_{t=0}^{n-1}
# \ln |f'(x_t)|
# \end{eqnarray}

# %% [markdown]
# Se tiene
# \begin{eqnarray}
# f'(x)
# &=&
# r(1-2x)
# \end{eqnarray}
# Por ende,
# \begin{eqnarray}
# f'(0)
# &=&
# r>0
# \end{eqnarray}
# luego, $x=0$ es punto fijo linealmente inestable para todo $r$.
#
# De manera similar,
# \begin{eqnarray}
# f'(1-r^{-1})
# &=&
# r
# \big(
# 1
# -
# 2(1-r^{-1})
# \big)
# \\
# &=&
# r
# \big(
# 1
# -
# 2+2r^{-1}
# \big)
# \\
# &=&
# r
# \big(
# -1+2r^{-1}
# \big)
# \\
# &=&
# -r+2
# \end{eqnarray}
# Por ende, $x=1-r^{-1}$ es punto fijo linealmente estable si
# $|2-r|<1$, i.e. si $r\in(1,3)$.
# Por otro lado, es linealmente inestable si $|2-r|>1$, i.e. si $r\in [0,1)\cup (3,\infty)$.
# Finlamente, es linealmente marginal si $|2-r|=1$, i.e. si $r=1$ o $r=3$.

# %%
# 2.a)

# %% [markdown]
# ## **Ejercicio 3)** El mapa de la carpa
#
# **a)** Repita el ejercicio **2)** pero para el mapa de la carpa:
#
# \begin{eqnarray}
# x_{t+1}
# &=&
# \bigg\{
# \begin{array}{ll}
# rx_t & 0\leq x_t\leq 1/2, \\
# r(1-x_t) & 1/2\leq x_t\leq 1
# \end{array}
# \end{eqnarray}
#
# definido para $X=[0,1]$ y $r\in [0,2]$.

# %%
# 3.a)

# %% [markdown]
# ## **Ejercicio 4)** El mapa del seno
#
# **a)** Repita el ejercicio **2)** pero para el mapa del seno:
#
# \begin{eqnarray}
# x_{t+1}
# =
# r\sin(\pi x_t)
# \end{eqnarray}
#
# definido para $X=[0,1]$ y $r\in [0,1]$.

# %%
# 4.a) y 4.b)
