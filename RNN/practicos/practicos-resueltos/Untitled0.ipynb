# %%
import numpy as np
import scipy as sp
import scipy.linalg as linalg
import matplotlib.pyplot as plt

# %%
np.matrix([[1,2],[3,4]])
# Out:
# matrix([[1, 2],
#         [3, 4]])

# %%
np.array([[1,2],[3,4]])
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
a = np.matrix([1,2,3,4])
b = np.matrix([3,3,2,2])

# %%
c = np.array([1,2,3,4])
d = np.array([3,3,2,2])

# %%
a*b.T
# Out:
# matrix([[23]])

# %%
c*d
# Out:
# array([3, 6, 6, 8])

# %%
c*d.T
# Out:
# array([3, 6, 6, 8])
